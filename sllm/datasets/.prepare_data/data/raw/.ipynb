# %% [markdown]
# ## 파일 컬럼 정리하기

# %%
import pandas as pd

df = pd.read_csv("t_figures_with_result_desc_v4.csv")
df.head(5)
# Out:
#           fig_id      pmid  original_label_id fig_label  \
# 0  38598310_fig1  38598310       470307513129      fig1
# 1  38598310_fig2  38598310       384174878961      fig2
# 2  38598310_fig3  38598310       161183008895      fig3
# 3  38598310_fig4  38598310       678947196634      fig4
# 4  38598310_fig5  38598310       683438586433      fig5
#
#                                          fig_caption  \
# 0  Reactions in the synthesis of VitD3:(i) electr...
# 1  Transition states for the antarafacial H-excha...
# 2  Examples of nonreactive(NR)+t−c and reactive +...
# 3  Molecule of PreD encapsulated inside the β-CD ...
# 4  Upper plots are bidimensional histograms repre...
#
#                                              fig_url  \
# 0  https://cdn.ncbi.nlm.nih.gov/pmc/blobs/039c/12...
# 1  https://cdn.ncbi.nlm.nih.gov/pmc/blobs/039c/12...
# 2  https://cdn.ncbi.nlm.nih.gov/pmc/blobs/039c/12...
# 3  https://cdn.ncbi.nlm.nih.gov/pmc/blobs/039c/12...
# ...

# %%
df.drop(columns=["structured_json"], inplace=True)

# %%
df.to_csv("t_figures_with_result_desc_v4.csv", index=False)

# %%
is_true_count = df['is_experiment_result'] == True
print("is_experiment_result=True인 데이터 갯수:", is_true_count.sum())
# Out:
# is_experiment_result=True인 데이터 갯수: 215
